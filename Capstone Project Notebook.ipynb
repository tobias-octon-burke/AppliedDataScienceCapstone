# %% [markdown]
# # Capstone Project

# %% [markdown]
# This notebook will be used to present work for the applied data science capstone project. This notebook should be available publicly on github.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
